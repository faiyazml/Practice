# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %%
A = [23,25,23,21,22]
B = [20,21,23,24,25]
C = [1,2,3,4,5]

plt.scatter(C,A)

plt.xlabel('Months')
plt.ylabel('Products Sold')
plt.title('Sales Peformance')

plt.show() # show is used to hide <matplotlib.collections.PathCollection at 0x14cdb340610>

# %%
plt.scatter(C,A, marker = 'D', color = 'Red', label = 'Person A')
plt.scatter(C,B, marker = 'H', color = 'Black', label = 'Person B')
plt.xlabel('Months')
plt.ylabel('Products Sold')
plt.title('Sales Peformance')
plt.grid() # this enable background lines
plt.legend() # to display words mentioned in label parameter
plt.show() # show is used to hide <matplotlib.collections.PathCollection at 0x14cdb340610>

# %%
plt.subplot(221) # 2 row and 2 columns , 1st graph
plt.scatter(C,A)
plt.ylabel('Y axis')

plt.subplot(222)
plt.plot(C,A) # line plot
plt.xlabel('X axis')
# Out:
# Text(0.5, 0, 'X axis')

# %%
plt.subplot(221) # 2 row and 2 columns , 1st graph
plt.scatter(C,A)
plt.ylabel('Y axis')

plt.subplot(222)
plt.plot(C,A) # line plot

plt.subplot(223) # 2 row and 2 columns , 1st graph
plt.scatter(C,B)
plt.ylabel('Y axis')

plt.subplot(224)
plt.plot(C,B) # line plot
plt.xlabel('X axis')

plt.show()

# %%
fig,axs = plt.subplots(2,2)

axs[0,0].scatter(C,A)
axs[0,1].plot(C,A)
axs[1,0].scatter(C,B)
axs[1,1].stackplot(C,B)

plt.show()

# %% [markdown]
# Import File in df1 Variable first

# %%
df1[(df1['mpg'] > 16.52 ) & (df1['mpg']<20.28)].shape

plt.hist(df1['mpg'], facecolor = 'red', edgecolor = 'black')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df1[(df1['mpg'] > 16.52 ) & (df1['mpg']<20.28)].shape
#       3 plt.hist(df1['mpg'], facecolor = 'red', edgecolor = 'black')
#
# NameError: name 'df1' is not defined

# %%
plt.boxplot(df1['acceleration'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.boxplot(df1['acceleration'])
#       2 plt.show()
#
# NameError: name 'df1' is not defined

# %%
df1[['mpg','acceleration','displacement','weight']].corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df1[['mpg','acceleration','displacement','weight']].corr()
#
# NameError: name 'df1' is not defined

# %% [markdown]
# #### Seaborn

# %%
sns.heatmap(df1[['mpg','acceleration','displacement','weight']].corr(), cmap = 'Blues',annot = True)
